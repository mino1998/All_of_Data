# %%
pip install selenium==3.141.0
# Out:
# Collecting selenium==3.141.0
#   Using cached selenium-3.141.0-py2.py3-none-any.whl (904 kB)
# Requirement already satisfied: urllib3 in c:\users\user\anaconda3\lib\site-packages (from selenium==3.141.0) (1.26.16)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0
# Note: you may need to restart the kernel to use updated packages.

# %%
def remove_newline(text):
    return text.replace('\n', '')

# %%
import os
# 시스템 PATH 확인
system_path = os.environ['PATH']
# 개별 경로들을 리스트 형태로 얻기
path_list = system_path.split(os.pathsep)

# 경로들 출력
for path in path_list:
    print(path)
# Out:
# C:\Users\USER\anaconda3
# C:\Users\USER\anaconda3\Library\mingw-w64\bin
# C:\Users\USER\anaconda3\Library\usr\bin
# C:\Users\USER\anaconda3\Library\bin
# C:\Users\USER\anaconda3\Scripts
# C:\Program Files\Common Files\Oracle\Java\javapath
# C:\Windows\system32
# C:\Windows
# C:\Windows\System32\Wbem
# C:\Windows\System32\WindowsPowerShell\v1.0\
# C:\Windows\System32\OpenSSH\
# C:\Program Files\Git\cmd
# C:\Program Files\Git\bin
# C:\Program Files\Docker\Docker\resources\bin
# C:\Program Files\nodejs\
# C:\Program Files\Bandizip\
# C:\Program Files\Java\jdk-17\bin
# C:\Program Files (x86)\Windows Kits\10\Windows Performance Toolkit\
# C:\Program Files\Graphviz\bin₩dot.exe
# C:\Users\USER\AppData\Local\Programs\Python\Python38\Scripts\
# C:\Users\USER\AppData\Local\Programs\Python\Python38\
# C:\Users\USER\AppData\Local\Microsoft\WindowsApps
# C:\Users\USER\AppData\Local\Programs\Microsoft VS Code\bin
# C:\Program Files\JetBrains\PyCharm 2023.1.3\bin
#
# C:\Users\USER\AppData\Roaming\npm
# C:\Program Files\Graphviz\bin

# %%
import sys
import os

# 프로젝트 폴더 절대 경로
project_folder = r'C:\Users\USER\Desktop\Hello_Vision\myprj'

# 시스템 PATH에 프로젝트 폴더를 추가
sys.path.append(project_folder)

# %%
from selenium import webdriver

# %% [markdown]
# ## Happy

# %%
# 기존 크롤링 코드랑 url빼고 유사합니다.
# melon DJ 크롤링 코드
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# 크롬드라이버를 설치한 경로 chromedriver.exe가 존재하는 path를 지정합니다.
webdriver_path = 'chromedriver'

# Chrome WebDriver 실행
browser = webdriver.Chrome(webdriver_path)

# 멜론 DJ 행복한 플레이리스트 중 첫번째 플리의 url을 가져왔습니다.
url = "https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=521608804"

browser.implicitly_wait(3)

browser.get(url)  # 페이지 접속

song_name_ls=[]

singer_ls=[]

lyrics_ls =[]

genre_ls=[]

cover_Is=[]

ytLink_ls=[]

from selenium.common.exceptions import NoSuchElementException


browser.implicitly_wait(3)
browser.get(url)  # 페이지 접속

song_num =1 # 1페이지의 1번노래부터, 이변수는 페이지를 넘어가기 위한 변수입니다.

page_number = 3 # 이 값은 몇 페이지까지 크롤링할것인지 정해주는 부분으로써, 유동적으로 변경한다.


for page in range(1,page_number+1):
    print(f"page {page} : ")
    
    # 크롤링 코드
    for i in range(1,50+1): # 한페이지당 50개의 음악이 존재한다.
        
        browser.execute_script("document.body.style.zoom='2%'") #화면 배율을 최대한 낮게하면 한화면에 모든 요소를 볼 수 있다.
        
        browser.implicitly_wait(3) # 대기시간 부여하는 코드
        
        search_button = browser.find_element(By.XPATH ,f'//*[@id="frm"]/div/table/tbody/tr[{i}]/td[4]/div/a') #음원정보로 연결되는 링크의 xpath이다.

        browser.implicitly_wait(1)

        search_button.send_keys(Keys.ENTER) # 위에서 찾은 음원의 정보페이지로 넘어가기(엔터키)


        browser.implicitly_wait(2)

        browser.execute_script("document.body.style.zoom='2%'") # 음원정보 페이지에서도 마찬가지로 배율 줄이기

        song_name=browser.find_element(By.XPATH ,'//*[@id="downloadfrm"]/div/div/div[2]/div[1]/div[1]') # 노래제목

        singer=browser.find_element(By.XPATH ,'//*[@id="downloadfrm"]/div/div/div[2]/div[1]/div[2]/a/span[1]') #가수명
        print(singer)

        genre=browser.find_element(By.XPATH ,'//*[@id="downloadfrm"]/div/div/div[2]/div[2]/dl/dd[3]') # 장르
        
        #앨범커버
        cover=browser.find_element(By.XPATH ,'//*[@id="downloadfrm"]/div/div/div[1]/a/img').get_attribute('src')
        
        
        
        try: #가사 정보가 없는 노래들에대한 예외처리
            search_button = browser.find_element(By.XPATH ,'//*[@id="lyricArea"]/button') 
            # 가사는 반으로 접혀있기때문에 더보기 버튼 찾기

            search_button.send_keys(Keys.ENTER) # 더보기 클릭
            
            lyrics_element = browser.find_element(By.XPATH, '//*[@id="d_video_summary"]')
            
            lyrics = lyrics_element.text
            
            
        except NoSuchElementException: # find_element에서 exception 발생하면 공백처리시켜주기
            lyrics =" "

        link="https://www.youtube.com/results?search_query="+singer.text+"+"+song_name.text # youtube 검색 링크
        
        song_name_ls.append(song_name.text) # 각리스트에 저장

        singer_ls.append(singer.text)

        genre_ls.append(genre.text)

        lyrics_ls.append(lyrics)
        
        cover_Is.append(cover)
        ytLink_ls.append(link)

        print(i," : ",song_name.text,singer.text, cover)

        
        browser.get(url)  # 기존페이지로 이동
        
        browser.implicitly_wait(3)

    
    song_num+= (50) # 다음 페이지로 넘어가기위해 50개씩 1부터 시작되므로 1,51,101,151 ... 이런식으로 시작index가 존재한다.
    url = f"https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=521608804#params%5BplylstSeq%5D=521608804&po=pageObj&startIndex={song_num}"
    #url마지막의 startIndex를 통해 페이지를 넘어가도록 하였다.

    browser.get(url)  # 다음페이지로 이동하기
    
    
    browser.implicitly_wait(3)
# Out:
# page 1 :
# <selenium.webdriver.remote.webelement.WebElement (session="8eb2249add3364a6965c95fd3324c33d", element="494FF78D968C5DE52ADF6FC32405F6A2_element_2014")>
# 1  :  Better Things aespa https://cdnimg.melon.co.kr/cm2/album/images/113/08/360/11308360_20230817161804_500.jpg?5efd31b7572748cb08d87c3aea065791/melon/resize/282/quality/80/optimize
# <selenium.webdriver.remote.webelement.WebElement (session="8eb2249add3364a6965c95fd3324c33d", element="432308DEFE8B81ACC19677BA33675842_element_4007")>
# 2  :  Bubble STAYC(스테이씨) https://cdnimg.melon.co.kr/cm2/album/images/113/05/820/11305820_20230814140002_500.jpg?a30acf3247ce355dbde860905e726fc3/melon/resize/282/quality/80/optimize
# <selenium.webdriver.remote.webelement.WebElement (session="8eb2249add3364a6965c95fd3324c33d", element
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:477, in WebElement.send_keys(self, *value)
#     474     if local_file is not None:
#     475         value = self._upload(local_file)
# --> 477 self._execute(Command.SEND_KEYS_TO_ELEMENT,
#     478               {'text': "".join(keys_to_typing(value)),
#     479                'value': keys_to_typing(value)})
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:633, in WebElement._execute(self, command, params)
#     631     params = {}
#     632 params['id'] = self._id
# --> 633 return self._parent.execute(command, params)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:321, in WebDriver.execute(self, driver_command, params)
#     319 response = self.command_executor.execute(driver_command, params)
#     320 if response:
# --> 321     self.error_handler.check_response(response)
#     322     response['value'] = self._unwrap_value(
#     323         response.get('value', None))
#     324     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:242, in ErrorHandler.check_response(self, response)
#     240         alert_text = value['alert'].get('text')
#     241     raise exception_class(message, screen, stacktrace, alert_text)
# --> 242 raise exception_class(message, screen, stacktrace)
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=116.0.5845.97)

# %%
import pandas as pd
happy = {}
for col,val in zip(['song','singer','genre','lyrics','cover', 'youtube'],[song_name_ls,singer_ls,genre_ls,lyrics_ls,cover_Is,ytLink_ls]):
    happy[col]=val

happy=pd.DataFrame(happy,columns=['song','singer','genre','lyrics','cover','youtube'])

# %%
happy
# Out:
#                                  song                singer     genre  \
# 0                       Better Things                 aespa        댄스
# 1                              Bubble           STAYC(스테이씨)        댄스
# 2    Seven (feat. Latto) - Clean Ver.                    정국        댄스
# 3                           LIP GLOSS       더보이즈 (THE BOYZ)        댄스
# 4                        Fast Forward                   전소미        댄스
# 5                                CAKE             ITZY (있지)      랩/힙합
# 6               여름이 들려 (Summer Comes)     오마이걸 (OH MY GIRL)        댄스
# 7                                 ETA              NewJeans        댄스
# 8                       Cool With You              NewJeans        댄스
# 9                                ISTJ             NCT DREAM        댄스
# 10                      Party O'Clock                 NMIXX        댄스
# 11                               I DO               (여자)아이들       POP
# 12                             I WANT             IVE (아이브)        댄스
# 13                         Cream Soda                   EXO        댄스
# 14                           In Bloom  ZEROBASEONE (제로베이스원)        댄스
# 15                    Do It Like That             투모로우바이투게더        댄스
# 16                          Super Shy              NewJeans        댄스
# 17                     Roller Coaster                 NMIXX        댄스
# 18                       One and Only           BOYNEXTDOOR        댄스
# 19                             돌아버리겠다           BOYNEXTDOOR        댄스
# 20                             #menow                프로미스나인        댄스
# 21  Hate Rodrigo (Feat. 우기 ((여자)아이들))            YENA (최예나)      록/메탈
# 22                               HARD          SHINee (샤이니)      랩/힙합
# 23                    Broken Melodies             NCT DREAM      록/메탈
# 24                      샤랄라 (SHALALA)          태용 (TAEYONG)      랩/힙합
# 25              이브, 프시케 그리고 푸른 수염의 아내    LE SSERAFIM (르세라핌)        댄스
# 26                                  특  Stray Kids (스트레이 키즈)      랩/힙합
# 27                           Take Two                 방탄소년단  R&B/Soul
# 28                               WAVE             IVE (아이브)     J-POP
# 29                            Bite Me               ENHYPEN        댄스
# 30                              Spicy                 aespa        댄스
# 31                     퀸카 (Queencard)               (여자)아이들        댄스
# 32                            Allergy               (여자)아이들        댄스
# 33                                손오공       세븐틴 (SEVENTEEN)        댄스
# 34                    Sugar Rush Ride             투모로우바이투게더        댄스
# 35                              KNOCK                   이채연        댄스
# 36    UNFORGIVEN (feat. Nile Rodgers)    LE SSERAFIM (르세라핌)        댄스
# 37                         Pink Venom             BLACKPINK      랩/힙합
# 38                       Alcohol-Free          TWICE (트와이스)        댄스
# 39                             GLASSY                   조유리        댄스
# 40                           Loveable                   조유리      록/메탈
# 41                        SET ME FREE          TWICE (트와이스)        댄스
# 42                               LOVE               (여자)아이들      록/메탈
# 43  Welcome To MY World (Feat. nævis)                 aespa  R&B/Soul
# 44                  Love Me Like This                 NMIXX        댄스
# 45                               Hurt              NewJeans  R&B/Soul
# 46                            Dolphin     오마이걸 (OH MY GIRL)        댄스
# 47                             Rollin           VANNER (배너)        댄스
# 48                              Candy             NCT DREAM        댄스
# 49                   살짝 설렜어 (Nonstop)     오마이걸 (OH MY GIRL)        댄스
# 50                      Better Things                 aespa        댄스
#
#                                                lyrics  \
# 0   Oh Got better things\nto do with my time\nBett...
# 1   Check it out now\nS.T.A.Y.C GO!\nIffy yo iffy ...
# 2   Weight of the world on your shoulders\nI kiss ...
# 3   LIP GLOSS LIP GLOSS\nI want to taste your LIP ...
# 4   I’m your future lover\n타락한 밤 너의 ruler\n영화 속 달콤...
# 5   ITZY ITZY like that!\nCake cake cake cake cake...
# 6   문득 네가 들리면, 고갤 돌리면,\n맘이 떨리면, 어느새 여름인가 봐 yeah ye...
# 7   낭비하지 마 네 시간은 은행\n서둘러서 정리해 걔는 real bad\n받아주면 안돼...
# 8   You know me like no other\n다 표현하지 않아도\nSee me ...
# 9   Introvert\n감각적\n사고적\n판단적\n\n널 해석\n16 Words\n필요...
# 10  It’s party time\n별이 깨어나는 까만 여름밤\nIt’s party ti...
# 11  Oh-oh-oh\nHit me like a shot in the heart\nNev...
# 12  예이예이예 음\n시끄럽게 쌓인 생각은 접어\n두근대는 리듬 즐겨 like festa...
# 13  톡 쏘는 듯한 느낌\n꽤나 부드러운 Cream\n섞일수록 더욱 진해져 Baby\n또...
# 14  아침이 와\n어제와 달라진 눈부신 Light\n눈을 뜨면\n움츠렸던 꽃잎은 피어나\...
# 15  You get me so off track\nBeen spinnin’ for mil...
# 16  I’m super shy, super shy\nBut wait a minute wh...
# 17  Mm-hmm, so incredible\nCan't you see, can't yo...
# 18  BOYNEXTDOOR,\nrepresenting KOZ, word up\n어느 옷을...
# 19  야 내가 미친 건지 함 들어봐\n손이 슬쩍 닿은듯한데\n날 보고 씩 웃네\n뭐 이리...
# 20  네모 칸 속 화려한 내 모습 And I know\n나를 향해 쏟아지는 Heart\n...
# 21  툭 하고 올 나간 스타킹\n높은 굽 말고 워커 살짝 머리핀\n누가 누굴 따라해 절대...
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# 크롬드라이버를 설치한 경로 chromedriver.exe가 존재하는 path를 지정합니다.
webdriver_path = 'chromedriver'

# Chrome WebDriver 실행
browser = webdriver.Chrome(webdriver_path)

# 멜론 DJ 슬픈 플레이리스트 중 첫번째 플리의 url을 가져왔습니다.
url = "https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=484083307"

browser.implicitly_wait(3)

browser.get(url)  # 페이지 접속

song_name_ls=[]

singer_ls=[]

lyrics_ls =[]

genre_ls=[]

cover_Is=[]

ytLink_ls=[]

from selenium.common.exceptions import NoSuchElementException


browser.implicitly_wait(3)
browser.get(url)  # 페이지 접속

song_num =1 # 1페이지의 1번노래부터, 이변수는 페이지를 넘어가기 위한 변수입니다.

page_number = 3 # 이 값은 몇 페이지까지 크롤링할것인지 정해주는 부분으로써, 유동적으로 변경한다.


for page in range(1,page_number+1):
    print(f"page {page} : ")
    
    # 크롤링 코드
    for i in range(1,50+1): # 한페이지당 50개의 음악이 존재한다.
        
        browser.execute_script("document.body.style.zoom='2%'") #화면 배율을 최대한 낮게하면 한화면에 모든 요소를 볼 수 있다.
        
        browser.implicitly_wait(3) # 대기시간 부여하는 코드
        
        search_button = browser.find_element(By.XPATH ,f'//*[@id="frm"]/div/table/tbody/tr[{i}]/td[4]/div/a') #음원정보로 연결되는 링크의 xpath이다.

        browser.implicitly_wait(1)

        search_button.send_keys(Keys.ENTER) # 위에서 찾은 음원의 정보페이지로 넘어가기(엔터키)


        browser.implicitly_wait(2)

        browser.execute_script("document.body.style.zoom='2%'") # 음원정보 페이지에서도 마찬가지로 배율 줄이기

        song_name=browser.find_element(By.XPATH ,'//*[@id="downloadfrm"]/div/div/div[2]/div[1]/div[1]') # 노래제목

        singer=browser.find_element(By.XPATH ,'//*[@id="downloadfrm"]/div/div/div[2]/div[1]/div[2]/a/span[1]') #가수명
        print(singer)

        genre=browser.find_element(By.XPATH ,'//*[@id="downloadfrm"]/div/div/div[2]/div[2]/dl/dd[3]') # 장르
        
        #앨범커버
        cover=browser.find_element(By.XPATH ,'//*[@id="downloadfrm"]/div/div/div[1]/a/img').get_attribute('src')
        
        
        
        try: #가사 정보가 없는 노래들에대한 예외처리
            search_button = browser.find_element(By.XPATH ,'//*[@id="lyricArea"]/button') 
            # 가사는 반으로 접혀있기때문에 더보기 버튼 찾기

            search_button.send_keys(Keys.ENTER) # 더보기 클릭
            
            lyrics_element = browser.find_element(By.XPATH, '//*[@id="d_video_summary"]')
            
            lyrics = lyrics_element.text
            
            
        except NoSuchElementException: # find_element에서 exception 발생하면 공백처리시켜주기
            lyrics =" "

        link="https://www.youtube.com/results?search_query="+singer.text+"+"+song_name.text # youtube 검색 링크
        
        song_name_ls.append(song_name.text) # 각리스트에 저장

        singer_ls.append(singer.text)

        genre_ls.append(genre.text)

        lyrics_ls.append(lyrics)
        
        cover_Is.append(cover)
        ytLink_ls.append(link)

        print(i," : ",song_name.text,singer.text, cover)

        
        browser.get(url)  # 기존페이지로 이동
        
        browser.implicitly_wait(3)

    
    song_num+= (50) # 다음 페이지로 넘어가기위해 50개씩 1부터 시작되므로 1,51,101,151 ... 이런식으로 시작index가 존재한다.
    url = f"https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=484083307#params%5BplylstSeq%5D=484083307&po=pageObj&startIndex={song_num}"
    #url마지막의 startIndex를 통해 페이지를 넘어가도록 하였다.

    browser.get(url)  # 다음페이지로 이동하기
    
    
    browser.implicitly_wait(3)
# Out:
# page 1 :
# <selenium.webdriver.remote.webelement.WebElement (session="38979ec41904ca990896623c0830c56e", element
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:477, in WebElement.send_keys(self, *value)
#     474     if local_file is not None:
#     475         value = self._upload(local_file)
# --> 477 self._execute(Command.SEND_KEYS_TO_ELEMENT,
#     478               {'text': "".join(keys_to_typing(value)),
#     479                'value': keys_to_typing(value)})
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:633, in WebElement._execute(self, command, params)
#     631     params = {}
#     632 params['id'] = self._id
# --> 633 return self._parent.execute(command, params)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:321, in WebDriver.execute(self, driver_command, params)
#     319 response = self.command_executor.execute(driver_command, params)
#     320 if response:
# --> 321     self.error_handler.check_response(response)
#     322     response['value'] = self._unwrap_value(
#     323         response.get('value', None))
#     324     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:242, in ErrorHandler.check_response(self, response)
#     240         alert_text = value['alert'].get('text')
#     241     raise exception_class(message, screen, stacktrace, alert_text)
# --> 242 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: stale element not found
#   (Session info: chrome=116.0.5845.97)

# %%
import pandas as pd
sad = {}
for col,val in zip(['song','singer','genre','lyrics','cover', 'youtube'],[song_name_ls,singer_ls,genre_ls,lyrics_ls,cover_Is,ytLink_ls]):
    sad[col]=val

sad=pd.DataFrame(sad,columns=['song','singer','genre','lyrics','cover','youtube'])

# %%
sad
# Out:
#                                song          singer         genre  \
# 0                                어른          Sondia    발라드, 국내드라마
# 1                꽃길 (Prod. By ZICO)             김세정           발라드
# 2                         아이와 나의 바다             아이유           발라드
# 3                               소나기   아이오아이 (I.O.I)           발라드
# 4                도망가자 (Run With Me)            선우정아      R&B/Soul
# 5                 먼저 말해줘 (Farewell)    태연 (TAEYEON)           발라드
# 6                                터널             김세정           발라드
# 7                       비밀 (Secret)    태연 (TAEYEON)           발라드
# 8                            다시 산다면              김필    발라드, 국내드라마
# 9                         생애 (LIFE)            선우정아      R&B/Soul
# 10                    당신이 지나간 자리, 꽃      HYNN (박혜원)           발라드
# 11                       깊은 밤을 보내줘요     오왠 (O.WHEN)     발라드, 인디음악
# 12                               화분             김세정           발라드
# 13                             별이되어             공기남     발라드, 인디음악
# 14                        Love poem             아이유          록/메탈
# 15                 오늘밤 잠 못 이루는 그대에게              류안     발라드, 인디음악
# 16                              목소리              김필           발라드
# 17                       오늘은 그런 날이야             안희수  인디음악, 포크/블루스
# 18                      잠이 오지 않는 오늘            메리애플     발라드, 인디음악
# 19                                짐      러비 (LOVEY)           발라드
# 20                        수고했어, 오늘도            옥상달빛  인디음악, 포크/블루스
# 21                     그대 오늘도 잘해냈어요             최한솔        포크/블루스
# 22                             서울살이             유승우  인디음악, 포크/블루스
# 23                              직업병            옥상달빛     발라드, 인디음악
# 24  흐르는 시간 속에 우리는 아름다워 (Album Ver.)      위수 (WISUE)  인디음악, 포크/블루스
# 25                     나의 하루는 너무 길다          안녕하신가영     발라드, 인디음악
# 26                               위로             권진아    발라드, 국내드라마
# 27                            종이비행기  우수한 (OOSU:HAN)    인디음악, 록/메탈
# 28  나의 작은 별에게 (Dear my little star)     정예원 (YEWON)     발라드, 인디음악
browser.implicitly_wait(3)
browser.get(url)  # 페이지 접속

song_num =1 # 1페이지의 1번노래부터, 이변수는 페이지를 넘어가기 위한 변수입니다.

page_number = 3 # 이 값은 몇 페이지까지 크롤링할것인지 정해주는 부분으로써, 유동적으로 변경한다.


for page in range(1,page_number+1):
    print(f"page {page} : ")
    
    # 크롤링 코드
    for i in range(1,50+1): # 한페이지당 50개의 음악이 존재한다.
        
        browser.execute_script("document.body.style.zoom='2%'") #화면 배율을 최대한 낮게하면 한화면에 모든 요소를 볼 수 있다.
        
        browser.implicitly_wait(3) # 대기시간 부여하는 코드
        
        search_button = browser.find_element(By.XPATH ,f'//*[@id="frm"]/div/table/tbody/tr[{i}]/td[4]/div/a') #음원정보로 연결되는 링크의 xpath이다.

        browser.implicitly_wait(1)

        search_button.send_keys(Keys.ENTER) # 위에서 찾은 음원의 정보페이지로 넘어가기(엔터키)


        browser.implicitly_wait(2)

        browser.execute_script("document.body.style.zoom='2%'") # 음원정보 페이지에서도 마찬가지로 배율 줄이기

        song_name=browser.find_element(By.XPATH ,'//*[@id="downloadfrm"]/div/div/div[2]/div[1]/div[1]') # 노래제목

        singer=browser.find_element(By.XPATH ,'//*[@id="downloadfrm"]/div/div/div[2]/div[1]/div[2]/a/span[1]') #가수명
        print(singer)

        genre=browser.find_element(By.XPATH ,'//*[@id="downloadfrm"]/div/div/div[2]/div[2]/dl/dd[3]') # 장르
        
        #앨범커버
        cover=browser.find_element(By.XPATH ,'//*[@id="downloadfrm"]/div/div/div[1]/a/img').get_attribute('src')
        
        
        
        try: #가사 정보가 없는 노래들에대한 예외처리
            search_button = browser.find_element(By.XPATH ,'//*[@id="lyricArea"]/button') 
            # 가사는 반으로 접혀있기때문에 더보기 버튼 찾기

            search_button.send_keys(Keys.ENTER) # 더보기 클릭
            
            lyrics_element = browser.find_element(By.XPATH, '//*[@id="d_video_summary"]')
            
            lyrics = lyrics_element.text
            
            
        except NoSuchElementException: # find_element에서 exception 발생하면 공백처리시켜주기
            lyrics =" "

        link="https://www.youtube.com/results?search_query="+singer.text+"+"+song_name.text # youtube 검색 링크
        
        song_name_ls.append(song_name.text) # 각리스트에 저장

        singer_ls.append(singer.text)

        genre_ls.append(genre.text)

        lyrics_ls.append(lyrics)
        
        cover_Is.append(cover)
        ytLink_ls.append(link)

        print(i," : ",song_name.text,singer.text, cover)

        
        browser.get(url)  # 기존페이지로 이동
        
        browser.implicitly_wait(3)

    
    song_num+= (50) # 다음 페이지로 넘어가기위해 50개씩 1부터 시작되므로 1,51,101,151 ... 이런식으로 시작index가 존재한다.
    url = f"https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=508674882#params%5BplylstSeq%5D=508674882&po=pageObj&startIndex={song_num}"
    #url마지막의 startIndex를 통해 페이지를 넘어가도록 하였다.

    browser.get(url)  # 다음페이지로 이동하기
    
    
    browser.implicitly_wait(3)
# Out:
# page 1 :
# <selenium.webdriver.remote.webelement.WebElement (session="9ca55fe4c2c36a72fb90a0c653f20b52", element
# 2                사랑을 사랑하게 될 때까지                잔나비 최정훈           발라드
# 3                  갑자기 생각이 난 건데                    김수영  인디음악, 포크/블루스
# 4                잠에 들지 못하는 그대에게       김뮤지엄 (KIMMUSEUM)      R&B/Soul
# ..                          ...                    ...           ...
# 145  눈물 나는 밤 (feat. 수민 (sumin))                 서교동의 밤     발라드, 인디음악
# 146                   Dear Moon           리플리 (RIPLEY)      R&B/Soul
# 147                          31                   카더가든          록/메탈
# 148                         있잖아             위수 (WISUE)  인디음악, 포크/블루스
# 149                     Rainbow  데이먼스 이어 (Damons year)     발라드, 인디음악
#
#                                                 lyrics  \
# 0    You will always be my girl\nI promise you\nI w...
# 1    I’m fall in love with you\nCan't take my eyes ...
# 2    불규칙적 통증처럼\n한동안은 그럴 거야\n가슴 한 켠이 답답하고 먹색일거야\n하늘하...
# 3    갑자기 생각이 난 건데\n조금 더 잘 해줄 걸 그랬나 봐\n이제는 느낄 수 없는 너...
# 4    잠에 들지 못하는 그대에게\n난 편지를 쓰네요\n다행인 듯 아닌 듯 오늘도\n너를 ...
# ..                                                 ...
# 145  우우우우 우우우우우\n우우우우우 Falling in Love\n거울 속을 들여다봐도...
# 146  모두가 곤히 잠든 밤\n저 달을 멍히 바라봐\n오늘따라 더 환하게\n빛나는 것만 같...
# 147  어느 가지에 돋아 맺힌 꽃\n침묵에 토라진 듯 차가워 돌아서는\n밤의 빗장을 뽑아 ...
# 148  있잖아 너를 내 눈으로\n몇 번이나 담고 붙잡았어\n그 셀 수 없는 몇 번쯤에\n나...
# 149  내가 바랬던 건\n그대가 아니에요\n하늘을 바라볼\n누군가가 필요했어\n그대가 없으...
#
#                                                  cover  \
# 0    https://cdnimg.melon.co.kr/cm/album/images/027...
# 1    https://cdnimg.melon.co.kr/cm2/album/images/11...
# 2    https://cdnimg.melon.co.kr/cm2/album/images/10...
# 3    https://cdnimg.melon.co.kr/cm2/album/images/10...
# 4    https://cdnimg.melon.co.kr/cm2/album/images/10...
# ..                                                 ...
# 145  https://cdnimg.melon.co.kr/cm2/album/images/10...
# 146  https://cdnimg.melon.co.kr/cm2/album/images/10...
# 147  https://cdnimg.melon.co.kr/cm2/album/images/10...
# 148  https://cdnimg.melon.co.kr/cm/album/images/102...
# 149  https://cdnimg.melon.co.kr/cm2/album/images/10...
#
#                                                youtube
# 0    https://www.youtube.com/results?search_query=스...
# 1    https://www.youtube.com/results?search_query=볼...
# 2    https://www.youtube.com/results?search_query=잔...
# 3    https://www.youtube.com/results?search_query=김...
# 4    https://www.youtube.com/results?search_query=김...
# ..                                                 ...
# 145  https://www.youtube.com/results?search_query=서...
# 146  https://www.youtube.com/results?search_query=리...
# 147  https://www.youtube.com/results?search_query=카...
# 148  https://www.youtube.com/results?search_query=위...
# 149  https://www.youtube.com/results?search_query=데...
#
# [150 rows x 6 columns]

# %%
calm.to_csv('calm0824.csv',index=False)

# %% [markdown]
# ## Top100 크롤링

# %%
# top100 코드
# 기존 크롤링 코드랑 url빼고 유사합니다.

from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# 크롬드라이버를 설치한 경로 chromedriver.exe가 존재하는 path를 지정합니다.
webdriver_path = 'chromedriver'

# Chrome WebDriver 실행
browser = webdriver.Chrome(webdriver_path)

url = "https://www.melon.com/chart/index.htm"

browser.implicitly_wait(5)

browser.get(url)  # 페이지 접속

song_name_ls=[]

singer_ls=[]

lyrics_ls =[]

genre_ls=[]

cover_Is=[]
ytLink_ls=[]

from selenium.common.exceptions import NoSuchElementException


browser.implicitly_wait(5)
browser.get(url)  # 페이지 접속

# song_num =1 # 1페이지의 1번노래부터, 이변수는 페이지를 넘어가기 위한 변수입니다.

# page_number = 3 # 이 값은 몇 페이지까지 크롤링할것인지 정해주는 부분으로써, 유동적으로 변경한다.


# for page in range(1,page_number+1):
#     print(f"page {page} : ")
    
    # 크롤링 코드
for i in range(1,100+1): # 한페이지당 50개의 음악이 존재한다.
        
        browser.execute_script("document.body.style.zoom='2%'") #화면 배율을 최대한 낮게하면 한화면에 모든 요소를 볼 수 있다.
        
        browser.implicitly_wait(5) # 대기시간 부여하는 코드
# /html/body/div/div[3]/div/div/div[3]/form/div/table/tbody/tr[1]/td[5]/div/a
# //*[@id="lst50"]/td[5]/div/a
        search_button = browser.find_element(By.XPATH ,f'/html/body/div/div[3]/div/div/div[3]/form/div/table/tbody/tr[{i}]/td[5]/div/a') #음원정보로 연결되는 링크의 xpath이다.
#//*[@id="frm"]/div/table/tbody/tr[{i}]/td[4]/div/a
        browser.implicitly_wait(5)

        search_button.send_keys(Keys.ENTER) # 위에서 찾은 음원의 정보페이지로 넘어가기(엔터키)


        browser.implicitly_wait(5)

        browser.execute_script("document.body.style.zoom='2%'") # 음원정보 페이지에서도 마찬가지로 배율 줄이기

        song_name=browser.find_element(By.XPATH ,'//*[@id="downloadfrm"]/div/div/div[2]/div[1]/div[1]') # 노래제목
#         //*[@id="downloadfrm"]/div/div/div[2]/div[1]/div[1]

        singer=browser.find_element(By.XPATH ,'//*[@id="downloadfrm"]/div/div/div[2]/div[1]/div[2]/a/span[1]') #가수명
#         //*[@id="downloadfrm"]/div/div/div[2]/div[1]/div[2]/a/span[1]
        genre=browser.find_element(By.XPATH ,'//*[@id="downloadfrm"]/div/div/div[2]/div[2]/dl/dd[3]') # 장르
#         //*[@id="downloadfrm"]/div/div/div[2]/div[2]/dl/dd[3]
        #앨범커버
        cover=browser.find_element(By.XPATH ,'//*[@id="downloadfrm"]/div/div/div[1]/a/img').get_attribute('src')
        
        
        try: #가사 정보가 없는 노래들에대한 예외처리
            search_button = browser.find_element(By.XPATH ,'//*[@id="lyricArea"]/button') 
            # 가사는 반으로 접혀있기때문에 더보기 버튼 찾기

            search_button.send_keys(Keys.ENTER) # 더보기 클릭
            
            lyrics_element = browser.find_element(By.XPATH, '//*[@id="d_video_summary"]')
            
            lyrics = lyrics_element.text
            
            
        except NoSuchElementException: # find_element에서 exception 발생하면 공백처리시켜주기
            lyrics =" "

        link="https://www.youtube.com/results?search_query="+singer.text+"+"+song_name.text # youtube 검색 링크   
        
        song_name_ls.append(song_name.text) # 각리스트에 저장

        singer_ls.append(singer.text)

        genre_ls.append(genre.text)

        lyrics_ls.append(lyrics)
        
        cover_Is.append(cover)
        ytLink_ls.append(link)
        print(i," : ",song_name.text,singer.text, cover)

        
        browser.get(url)  # 기존페이지로 이동
        
        browser.implicitly_wait(3)

    
#     song_num+= (50) # 다음 페이지로 넘어가기위해 50개씩 1부터 시작되므로 1,51,101,151 ... 이런식으로 시작index가 존재한다.
#     url = f"https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=490527225#params%5BplylstSeq%5D=490527225&po=pageObj&startIndex={song_num}"
#     #url마지막의 startIndex를 통해 페이지를 넘어가도록 하였다.

#     browser.get(url)  # 다음페이지로 이동하기
    
    
#     browser.implicitly_wait(3)
# Out:
# 1  :  Seven (feat. Latto) - Clean Ver. 정국 https://cdnimg.melon.co.kr/cm2/album/images/112/86/070/11286070_20230713181059_500.jpg?0b3a98d363e31435d805d60e3041a54b/melon/resize/282/quality/80/optimize
# 2  :  ETA NewJeans https://cdnimg.melon.co.kr/cm2/album/images/112/81/456/11281456_20230706180841_500.jpg?adcd1e7bd5800378cd55ef3b7b5ffb8f/melon/resize/282/quality/80/optimize
# 3  :  Super Shy NewJeans https://cdnimg.melon.co.kr/cm2/album/images/112/81/456/11281456_20230706180841_500.jpg?adcd1e7bd5800378cd55ef3b7b5ffb8f/melon/resize/282/quality/80/optimize
# 4  :  헤어지자 말해요 박재정 https://cdnimg.melon.co.kr/cm2/album/images/112/27/533/11227533_20230419162238_500.jpg?f2aaefe2470b9694d40b0ad16df118a6/melon/resize/282/quality/80/optimize
# 5  :  퀸카 (Queencard) (여자)아이들 https://cdnimg.melon.co.kr/cm2/album/images/112/40/232/11240232_20230509151820_500.jpg?33713173eb47f6371b513e171f80e2c9/melon/resize/282/quality/80/optimize
# 6  :  사막에서 꽃을 피우듯 우디 (Woody) https://cdnimg.melon.co.kr/cm2/album/images/112/85/867/11285867_20230713162404_500.jpg?99a13fafd660587d711b4a977ecf3c5e/melon/resize/282/quality/80/optimize
# 7  :  I AM IVE (아이브) https://cdnimg.melon.co.kr/cm2/album/images/112/11/297/11211297_20230410151046_500.jpg?1af1b1d675154cbc4d581f9b36c75ebf/melon/resize/282/quality/80/optimize
# 8  :  Steal The Show (From “엘리멘탈”) Lauv https://cdnimg.melon.co.kr/cm2/album/images/112/54/858/11254858_20230531233847_500.jpg?bbc15539cb524942c7ecdf7e1389b81f/melon/resize/282/quality/80/optimize
# 9  :  Fast Forward 전소미 https://cdnimg.melon.co.kr/cm2/album/images/113/00/771/11300771_20230807190540_500.jpg?f251b5719dfeee03cd436bae9b51ef9f/melon/resize/282/quality/80/optimize
# 10  :  New Jeans NewJeans https://cdnimg.melon.co.kr/cm2/album/images/112/81/456/11281456_20230706180841_500.jpg?adcd1e7bd5800378cd55ef3b7b5ffb8f/melon/resize/282/quality/80/optimize
# 11  :  모래 알갱이 임영웅 https://cdnimg.melon.co.kr/cm2/album/images/112/58/233/11258233_20230605094802_500.jpg?7bf471c22bdec53ff285fa06b18dcbff/melon/resize/282/quality/80/optimize
# 100  :  Nxde (여자)아이들 https://cdnimg.melon.co.kr/cm2/album/images/110/78/852/11078852_20221017102947_500.jpg?3afd315fe8957d40a511b9c42aeaf516/melon/resize/282/quality/80/optimize

# %%
import pandas as pd
top = {}
for col,val in zip(['song','singer','genre','lyrics','cover','youtube'],[song_name_ls,singer_ls,genre_ls,lyrics_ls,cover_Is,ytLink_ls]):
    top[col]=val

top_df=pd.DataFrame(top,columns=['song','singer','genre','lyrics','cover','youtube'])

# %%
top_df
# Out:
#                                 song    singer       genre  \
# 0   Seven (feat. Latto) - Clean Ver.        정국          댄스
# 1                                ETA  NewJeans          댄스
# 2                          Super Shy  NewJeans          댄스
# 3                           헤어지자 말해요       박재정         발라드
# 4                     퀸카 (Queencard)   (여자)아이들          댄스
# ..                               ...       ...         ...
# 95                         빛이 나는 너에게  던 (DAWN)    R&B/Soul
# 96                      Heaven(2023)       임재현  발라드, 국내드라마
# 97                          LOCKDOWN    이세계아이돌          댄스
# 98                         Monologue        테이         발라드
# 99                              Nxde   (여자)아이들          댄스
#
#                                                lyrics  \
# 0   Weight of the world on your shoulders\nI kiss ...
# 1   낭비하지 마 네 시간은 은행\n서둘러서 정리해 걔는 real bad\n받아주면 안돼...
# 2   I’m super shy, super shy\nBut wait a minute wh...
# 3   헤어지자고 말하려 오늘\n너에게 가다가 우리 추억 생각해 봤어\n처음 본 네 얼굴\...
# 4   Hey you\n뭘 보니? 내가 좀 Sexy Sexy 반했니\nYe you\n뭐 하...
# ..                                                ...
# 95  그때 널 만나지 않았더라면\n지금의 우린 어디에 있을까\n가장 예쁠 때의 너를 만나...
# 96  왜 이제 왔나요 더 야윈 그대\n나만큼 힘들었나요\n두 번 살게 하네요 그대 내 삶...
# 97  oh you can't stop me\n못 멈춰 감히\n손끝 하나도 건드리지 못하는...
# 98  다 잊었다는 거짓말\n또 해 버렸죠\n내 마음에 그대란 사람\n없다고 했죠\n너무나...
# 99  Why you think that ’bout nude\n’Cause your vie...
#
#                                                 cover  \
# 0   https://cdnimg.melon.co.kr/cm2/album/images/11...
# 1   https://cdnimg.melon.co.kr/cm2/album/images/11...
# 2   https://cdnimg.melon.co.kr/cm2/album/images/11...
# 3   https://cdnimg.melon.co.kr/cm2/album/images/11...
# 4   https://cdnimg.melon.co.kr/cm2/album/images/11...
# ..                                                ...
# 95  https://cdnimg.melon.co.kr/cm2/album/images/11...
# 96  https://cdnimg.melon.co.kr/cm2/album/images/11...
# 97  https://cdnimg.melon.co.kr/cm2/album/images/11...
# 98  https://cdnimg.melon.co.kr/cm2/album/images/11...
# 99  https://cdnimg.melon.co.kr/cm2/album/images/11...
#
#                                               youtube
# 0   https://www.youtube.com/results?search_query=정...
# 1   https://www.youtube.com/results?search_query=N...
# 2   https://www.youtube.com/results?search_query=N...
# 3   https://www.youtube.com/results?search_query=박...
# 4   https://www.youtube.com/results?search_query=(...
# ..                                                ...
# 95  https://www.youtube.com/results?search_query=던...
# 96  https://www.youtube.com/results?search_query=임...
# 97  https://www.youtube.com/results?search_query=이...
# 98  https://www.youtube.com/results?search_query=테...
# 99  https://www.youtube.com/results?search_query=(...
#
# [100 rows x 6 columns]

# %%
top_df.to_csv('top0824.csv',index=False)
